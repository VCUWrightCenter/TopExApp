# %%
import medtop.core as medtop

# %%
data, doc_df = medtop.import_from_files('../../data/corpus_file_list.txt')
data.shape
# Out:
# (79, 6)

# %%
clusteringMethod = 'hac'
k=None
height=None

tfidf, dictionary = medtop.create_tfidf(doc_df,seed_topics_df=None)
data = medtop.get_phrases(data, dictionary.token2id, tfidf, include_input_in_tfidf = True, window_size=6, include_sentiment=True)
data = medtop.get_vectors("tfidf", data, dictionary = dictionary, tfidf = tfidf)
# Out:
# Removed 0 sentences without phrases.

# %%
medtop.assign_clusters(data, method='hac', k=None, height=None, dist_metric='euclidean')
# Out:
# c:\users\etfrench\appdata\local\programs\python\python38\lib\site-packages\scipy\cluster\hierarchy.py:830: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')
#                id  doc_id  sent_id  \
# 0    doc.0.sent.0       0        0
# 1    doc.0.sent.1       0        1
# 2    doc.0.sent.2       0        2
# 3    doc.0.sent.3       0        3
# 4    doc.0.sent.4       0        4
# ..            ...     ...      ...
# 65  doc.3.sent.12       3       12
# 66  doc.3.sent.13       3       13
# 67  doc.3.sent.14       3       14
# 68  doc.3.sent.15       3       15
# 69  doc.3.sent.18       3       18
#
#                                                  text  \
# 0   I felt guilt because I was caught out lying ab...
# 1   I felt joy because I was going to South Africa...
# 2   I felt joy because I was going to see my favou...
# ...
